# %%
from utils import Duel, parzival, gawan, feirefiz, cundrie, orgeluse, arthur

# %%
print("=" * 60)
print("PARZIVAL DUEL GAME - Special Abilities Test")
print("=" * 60)

# Example 1: Parzival vs Gawan
print("\n" + "=" * 60)
print("Example 1: Parzival vs Gawan")
print("=" * 60)
duel1 = Duel(parzival, "Martial", "Diplomacy", gawan, "Martial", "Diplomacy")
duel1.play()

# Example 2: Feirefiz vs Parzival (brothers!)
print("\n" + "=" * 60)
print("Example 2: Feirefiz vs Parzival (brothers!)")
print("=" * 60)
duel2 = Duel(feirefiz, "Martial", "Diplomacy", parzival, "Martial", "Intrigue")
duel2.play()

# Example 3: Cundrie using her ability
print("\n" + "=" * 60)
print("Example 3: Cundrie vs Orgeluse (with ability)")
print("=" * 60)
print(f"\nBefore ability - Orgeluse stats: {orgeluse.traits}")
cundrie.use_oppressor(orgeluse)
print(f"After ability - Orgeluse stats: {orgeluse.traits}")
duel3 = Duel(cundrie, "Learning", "Stewardship", orgeluse, "Intrigue", "Diplomacy")
duel3.play()

# Example 4: Arthur summoning knights
print("\n" + "=" * 60)
print("Example 4: Arthur summoning the Round Table")
print("=" * 60)
print(f"\nArthur's initial stats: {arthur.traits}")
arthur.summon_knight("Kay")
print(f"After summoning Kay: {arthur.traits}")
arthur.summon_knight("Lanzelet")
print(f"After summoning Lanzelet: {arthur.traits}")
arthur.summon_knight("Kay")  # Try to summon again (should fail)

print("\n" + "=" * 60)
print("Character Status Summary")
print("=" * 60)
for char in [parzival, gawan, feirefiz, cundrie, orgeluse, arthur]:
    print(f"\n{char.name}:")
    print(f"  Stats: {char.traits}")
    print(f"  Special: {char.special}")
    if hasattr(char, 'ability_uses'):
        print(f"  Remaining uses: {char.ability_uses}")
# Out:
# ...
# PARZIVAL DUEL GAME - Special Abilities Test
# ...
#
# ...
# Example 1: Parzival vs Gawan
# ...
#
# ⚔️  DUEL: Parzival vs Gawan
#   Parzival: Martial=20, Diplomacy=10
#   Gawan: Martial=18, Diplomacy=14
#   🛡️  Parzival uses 'For Herzeloyde!' - ignores 1 minor damage! (3 uses remaining)
#   🛡️  Gawan uses 'Arm of Waleis!' - ignores 3 major damage!
#
# ...
# Example 2: Feirefiz vs Parzival (brothers!)
# ...
#
# ⚔️  DUEL: Feirefiz vs Parzival
#   Feirefiz: Martial=19, Diplomacy=9
#   Parzival: Martial=20, Intrigue=11
#   🛡️  Feirefiz uses 'Sons of Gahmurat!' - brothers never harm each other! (ignores 1 major damage)
#   🛡️  Parzival uses 'For Herzeloyde!' - ignores 1 minor damage! (2 uses remaining)
#   ⚔️  Feirefiz's bond with his brother makes him stronger! (all non-Martial stats +1)
#
# ...
# Example 3: Cundrie vs Orgeluse (with ability)
# ...
#
# Before ability - Orgeluse stats: {'Diplomacy': 16, 'Martial': 8, 'Stewardship': 12, 'Intrigue': 17, 'Learning': 13}
# ...
