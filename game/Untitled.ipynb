# %%
from utils import Character, Duel, AFFINITIES

# %%
parzival = Character(
    name="Parzival",
    honor=10,
    diplo=10,
    marti=20,
    stewa=9,
    intri=11,
    learn=5,
    special=None
)

gawan = Character(
    name="Gawan",
    honor=10,
    diplo=14,
    marti=18,
    stewa=12,
    intri=11,
    learn=10,
    special=None
)

# %%
duel = Duel(parzival, "Diplomacy", "Martial", gawan, "Diplomacy", "Martial")
dmgs = duel.play()
print(dmgs)
# Out:
# (5, 1)
